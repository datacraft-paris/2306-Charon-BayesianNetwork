# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, f1_score, fbeta_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from datetime import date
import time

import numpy as np
from statistics import mean
from sklearn.impute import KNNImputer
from sklearn import preprocessing

import matplotlib.pyplot as plt

from pyAgrum.lib.bn2roc import showROC_PR

# %%
from IPython.display import IFrame

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
import lightgbm

# %%
from matplotlib import pylab
import ipywidgets

# %%
import pyAgrum as gum

# %%
import pyAgrum.skbn as skbn
import pyAgrum.lib.notebook as gnb
import pyAgrum.lib.explain as exp

# %%
df = pd.read_csv('df_pretreat.csv')

# %%
for col in df.describe(include='object').columns:
    df[col] = df[col].astype('str')

# %% [markdown]
# # Apprentissage

# %%
seuil_rappel = 0.90

def score_perso(y_valid, y_pred):
    
    total = y_valid.sum()
    
    def recall_for(x):
        found = ((y_pred > x) & (y_valid == 1)).sum()
        return float(found) / total
    
    x = 0.995
    while recall_for(x) < seuil_rappel and x > 0.005:
        x -= 0.005
        
    return (y_pred > x).sum() / float(len(y_valid))

# %%
def apprentissage(df, learningMethod, beta=1, usePR=True, courbes=True, save_fig=True) :
    X_train, X_test, Y_train, Y_test = train_test_split(df.drop('cible', axis=1), df['cible'],
                                                        shuffle=True, test_size=0.25)

    df_train = pd.concat([X_train, Y_train], axis=1)
    
    cl = skbn.BNClassifier(learningMethod=learningMethod, usePR=usePR,beta=beta,
                           discretizationThreshold=33)
    cl.fit(X_train, Y_train)
    gum.lib.bn2roc.showROC_PR(cl.bn,df_train,'cible', 1, beta=beta, show_progress=True,
                              show_fig=True, save_fig=save_fig, with_labels=True)
    y_test_pred = cl.predict(X_test)

    print("Results on test set :")
    print(f"F-score : {f1_score(Y_test, y_test_pred):.2f}")
    print(f"F2-score : {fbeta_score(Y_test, y_test_pred, beta=2):.2f}")
    print(f"Precision : {precision_recall_fscore_support(Y_test, y_test_pred)[0][1]:.2f}")
    print(f"Recall : {precision_recall_fscore_support(Y_test, y_test_pred)[1][1]:.2f}")
    print(f"Accuracy : {accuracy_score(Y_test, y_test_pred):.2f}")

    print("Confusion Matrix")
    print(confusion_matrix(Y_test, y_test_pred))
    
    print(f"Score Perso : {score_perso(Y_test, y_test_pred):.2f}")

    return cl

# %% [markdown]
# ## Greedy Hill Climbing

# %%
cl_GHC = apprentissage(df, learningMethod='GHC', beta=2, save_fig=False)
# Out:
# dataframe: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████|
# Results on test set :
# F-score : 0.40
# F2-score : 0.54
# Precision : 0.28
# Recall : 0.70
# Accuracy : 0.71
# Confusion Matrix
# [[4144 1638]
#  [ 272  632]]
# Score Perso : 0.34

# %%
cl_GHC.MarkovBlanket
# Out:
# (pyAgrum.BayesNet<double>@000001A6B1D44330) BN{nodes: 7, arcs: 7, domainSize: 648, dim: 68, mem: 968o}

# %%
gum.lib.bn2roc.animPR(cl_GHC.bn, df, target="cible", label="1")
# Out:
# interactive(children=(IntSlider(value=50, description='rate'), Output(layout=Layout(height='250px'))), _dom_cl…

# %%
gnb.showInference(cl_GHC.MarkovBlanket)

# %%
gnb.showGraph(exp.nestedMarkovBlankets(cl_GHC.bn, 'cible',2), size='10!')

# %%
len(exp.nestedMarkovBlanketsNames(cl_GHC.bn, 'cible',2))
# Out:
# 57

# %% [markdown]
# ## MIIC

# %%
#cl_MIIC = apprentissage(df, learningMethod='MIIC', beta=2)

# %%
bn_miic = gum.loadBN('bn_miic.bifxml')

# %%
gum.lib.bn2roc.showROC_PR(bn_miic, df_train,'cible', 1, beta=3, show_progress=True,
                          show_fig=True, save_fig=True, with_labels=True)

# %%
cl_MIIC = skbn.BNClassifier()

# %%
cl_MIIC.fromTrainedModel(bn = bn_miic, targetAttribute = 'cible', targetModality = '1',
                             threshold = 0.5)

# %%
cl_MIIC.MarkovBlanket

# %%
gnb.showGraph(exp.nestedMarkovBlankets(bn_miic, 'cible',2), size='10!')

# %% [markdown]
# ## Other ML models

# %%
df_label = df.copy()

for col in df_label.columns:
    if df_label[col].dtype == object:
        lb_make = preprocessing.LabelEncoder()
        df_label[col] = lb_make.fit_transform(df_label[col])

# %%
names = ["Logistic Regression", "Decision Tree", "Random Forest", 
         "Neural Net", "AdaBoost", "Naive Bayes", "QDA", "XgBoost", "LGBM"]

classifiers = [LogisticRegression(max_iter=1000), DecisionTreeClassifier(), RandomForestClassifier(),
               MLPClassifier(), AdaBoostClassifier(), GaussianNB(), QuadraticDiscriminantAnalysis(), 
               XGBClassifier(), lightgbm.LGBMClassifier()]
    
res = []


for cla in range(len(classifiers)) :
    print(names[cla])

    X_train, X_test, Y_train, Y_test = train_test_split(df_label.drop('cible', axis=1), df_label['cible'],
                                                        shuffle=True, test_size=0.25)
    df_test = pd.concat([X_test, Y_test], axis=1)
                
    cl = classifiers[cla]

    try : 
        cl.fit(X_train, Y_train)

    except  Exception as error:
        print("An exception occurred:", type(error).__name__, "–", error)
        break 

    y_test_pred = cl.predict(X_test)

    res.append(fbeta_score(Y_test, y_test_pred, beta=2))

    print(f"F-score : {f1_score(Y_test, y_test_pred):.2f}")
    print(f"F2-score : {fbeta_score(Y_test, y_test_pred, beta=2):.2f}")
    print(f"Precision : {precision_recall_fscore_support(Y_test, y_test_pred)[0][1]:.2f}")
    print(f"Recall : {precision_recall_fscore_support(Y_test, y_test_pred)[1][1]:.2f}")
    print(f"Accuracy : {accuracy_score(Y_test, y_test_pred):.2f}")
    print("Confusion Matrix :")
    print(confusion_matrix(Y_test, y_test_pred))
    print(f"Score Perso : {score_perso(Y_test, y_test_pred):.2f}")
    
    print('\n')
# Out:
# Logistic Regression
# C:\Users\I534120\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# F-score : 0.38
# F2-score : 0.31
# Precision : 0.63
# Recall : 0.27
# Accuracy : 0.87
# Confusion Matrix :
# [[5581  151]
#  [ 695  259]]
# Score Perso : 0.06
#
#
# Decision Tree
# F-score : 0.42
# F2-score : 0.44
# Precision : 0.39
# Recall : 0.45
# Accuracy : 0.83
# Confusion Matrix :
# [[5094  654]
#  [ 513  425]]
# Score Perso : 0.16
#
#
# Random Forest
# F-score : 0.43
# F2-score : 0.35
# Precision : 0.71
# Recall : 0.31
# Accuracy : 0.88
# Confusion Matrix :
# [[5595  122]
#  [ 668  301]]
# Score Perso : 0.06
#
#
# Neural Net
# C:\Users\I534120\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# F-score : 0.48
# F2-score : 0.47
# Precision : 0.50
# Recall : 0.46
# Accuracy : 0.86
# Confusion Matrix :
# [[5270  443]
#  [ 524  449]]
# Score Perso : 0.13
#
#
# AdaBoost
# F-score : 0.40
# F2-score : 0.32
# Precision : 0.68
# Recall : 0.29
# Accuracy : 0.88
# Confusion Matrix :
# [[5598  127]
#  [ 685  276]]
# Score Perso : 0.06
#
#
# Naive Bayes
# F-score : 0.37
# F2-score : 0.52
# Precision : 0.25
# Recall : 0.71
# Accuracy : 0.66
# Confusion Matrix :
# [[3727 2018]
#  [ 271  670]]
# Score Perso : 0.40
#
#
# QDA
# C:\Users\I534120\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\discriminant_analysis.py:935: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# F-score : 0.26
# F2-score : 0.46
# Precision : 0.15
# Recall : 0.98
# Accuracy : 0.17
# Confusion Matrix :
# [[ 149 5566]
#  [  15  956]]
# Score Perso : 0.98
#
#
# XgBoost
# C:\Users\I534120\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:297: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# C:\Users\I534120\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:299: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# C:\Users\I534120\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:364: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# C:\Users\I534120\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:297: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# C:\Users\I534120\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:299: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_categorical_dtype(dtype) and enable_categorical:
# F-score : 0.49
# F2-score : 0.42
# Precision : 0.70
# Recall : 0.38
# Accuracy : 0.88
# Confusion Matrix :
# [[5529  163]
#  [ 617  377]]
# Score Perso : 0.08
#
#
# LGBM
# [LightGBM] [Info] Number of positive: 2887, number of negative: 17168
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009798 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 426
# [LightGBM] [Info] Number of data points in the train set: 20055, number of used features: 156
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.143954 -> initscore=-1.782829
# [LightGBM] [Info] Start training from score -1.782829
# F-score : 0.49
# F2-score : 0.41
# Precision : 0.74
# Recall : 0.37
# Accuracy : 0.89
# Confusion Matrix :
# [[5616  120]
#  [ 602  348]]
# Score Perso : 0.07

# %%
points=bn2roc.getROCpoints(cl_GHC.bn, df_test, 'cible', 1)
x=[point[0] for point in points]
y=[point[1] for point in points]
plt.plot(x,y,label="GHC")

points=bn2roc.getROCpoints(cl_MIIC.bn, df_test, 'cible', 1)
x1=[point[0] for point in points]
y1=[point[1] for point in points]
plt.plot(x1,y1,label="MIIC")

points=bn2roc.getROCpoints(classif2.bn, "res/titanic/post_train.csv", 'Survived', "True")
x2=fpr_XGB
y2=tpr_XGB
plt.plot(x2,y2,label="XgBoost")

points=bn2roc.getROCpoints(classif3.bn, "res/titanic/post_train.csv", 'Survived', "True")
x3=fpr_LGBM
y3=tpr_LGBM
plt.plot(x3,y3,label="LGBM")

plt.title("Comparing ROC from all models")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 points=bn2roc.getROCpoints(cl_GHC.bn, df_test, 'cible', 1)
#       2 x=[point[0] for point in points]
#       3 y=[point[1] for point in points]
#
# NameError: name 'bn2roc' is not defined

# %% [markdown]
# ## Shap Values

# %%
def compute_shap_bn(df, mb, train_sample=0.2, target='cible'):

    df_mb = df[list(mb.names())]
    print(mb.names())

    gumshap = exp.ShapValues(mb, target)
    train = df_mb.sample(frac=train_sample)
    t_start = time.time()
    plt.plot()
    marginal = gumshap.marginal(train, plot=True, plot_importance=True, percentage=False)
    plt.figure()
    print(f'Run Time : {time.time() - t_start} sec')


    return gumshap.results

# %%
res = compute_shap_bn(df, cl_GHC.MarkovBlanket)
